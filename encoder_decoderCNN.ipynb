# %% [markdown]
# <a href="https://colab.research.google.com/github/snowden141/ContactReader/blob/master/encoder_decoderCNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/arahusky/Tensorflow-Segmentation
# Out:
# Cloning into 'Tensorflow-Segmentation'...
# remote: Enumerating objects: 26322, done.
# remote: Total 26322 (delta 0), reused 0 (delta 0), pack-reused 26322
# Receiving objects: 100% (26322/26322), 122.86 MiB | 12.04 MiB/s, done.
# Resolving deltas: 100% (454/454), done.
# Checking out files: 100% (26383/26383), done.

# %%
# !pip install https://storage.googleapis.com/tensorflow/linux/gpu/tensorflow_gpu-1.12.0-cp35-cp35m-linux_x86_64.whl
# Out:
# tensorflow_gpu-1.12.0-cp35-cp35m-linux_x86_64.whl is not a supported wheel on this platform.

# %%
# !pip list
# Out:
# Package                  Version
# ------------------------ ---------------------
# absl-py                  0.7.1
# alabaster                0.7.12
# albumentations           0.1.12
# altair                   2.4.1
# astor                    0.7.1
# astropy                  3.0.5
# atari-py                 0.1.7
# atomicwrites             1.3.0
# attrs                    19.1.0
# audioread                2.1.6
# autograd                 1.2
# Babel                    2.6.0
# backcall                 0.1.0
# backports.tempfile       1.0
# backports.weakref        1.0.post1
# beautifulsoup4           4.6.3
# bleach                   3.1.0
# bokeh                    1.0.4
# boto                     2.49.0
# boto3                    1.9.123
# botocore                 1.12.123
# Bottleneck               1.2.1
# branca                   0.3.1
# bs4                      0.0.1
# bz2file                  0.98
# cachetools               3.1.0
# certifi                  2019.3.9
# ...

# %%
# !ls
# Out:
# sample_data  Tensorflow-Segmentation

# %%
# !ls Tensorflow-Segmentation/data128_128/inputs
# Out:
# Aaron_Peirsol_0001.jpg
# Aaron_Peirsol_0002.jpg
# Aaron_Peirsol_0003.jpg
# Aaron_Peirsol_0004.jpg
# Aaron_Sorkin_0001.jpg
# Aaron_Sorkin_0002.jpg
# Abdel_Nasser_Assidi_0001.jpg
# Abdel_Nasser_Assidi_0002.jpg
# Abdoulaye_Wade_0004.jpg
# Abdullah_0001.jpg
# Abdullah_0002.jpg
# Abdullah_0003.jpg
# Abdullah_0004.jpg
# Abdullah_al-Attiyah_0001.jpg
# Abdullah_al-Attiyah_0002.jpg
# Abdullah_al-Attiyah_0003.jpg
# Abdullah_Nasseef_0001.jpg
# Abdul_Rahman_0001.jpg
# Abel_Pacheco_0001.jpg
# Abel_Pacheco_0003.jpg
# Abel_Pacheco_0004.jpg
# Abner_Martinez_0001.jpg
# Adam_Sandler_0001.jpg
# Adam_Sandler_0002.jpg
# Adam_Sandler_0003.jpg
# Adam_Sandler_0004.jpg
# Adam_Scott_0001.jpg
# Adam_Scott_0002.jpg
# Adolfo_Aguilar_Zinser_0001.jpg
# Adolfo_Aguilar_Zinser_0003.jpg
# Adolfo_Rodriguez_Saa_0001.jpg
# Adrian_Nastase_0002.jpg
# Afton_Smith_0001.jpg
# Ahmed_Ahmed_0001.jpg
# Ahmed_Chalabi_0001.jpg
# Ahmed_Chalabi_0002.jpg
# Ahmed_Chalabi_0004.jpg
# Ahmed_Lopez_0001.jpg
# Ahmet_Demir_0001.jpg
# ...

# %%
# !cd Tensorflow-Segmentation

# %%
# !mv Tensorflow-Segmentation/* ./

# %%
# !ls
# Out:
# conv2d.py		      infer.py	      project_summary.pdf
# convolutional_autoencoder.py  layer.py	      README.md
# data128_128		      libs	      results.png
# data250_250		      max_pool_2d.py  sample_data
# data28_28		      model.png       Tensorflow-Segmentation
# imgaug			      notebooks       utils.py

# %%
# !python convolutional_autoencoder.py
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/tensor_array_ops.py:162: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/image_ops_impl.py:1241: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
#
# WARNING: The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
# If you depend on functionality not listed there, please file an issue.
#
# Current input shape:  (?, 2, 2, 64)
# ...

# %%
# !ls
# Out:
# conv2d.py		      layer.py		   README.md
# convolutional_autoencoder.py  libs		   results.png
# data128_128		      logs		   sample_data
# data250_250		      max_pool_2d.py	   save
# data28_28		      model.png		   Tensorflow-Segmentation
# image_plots		      notebooks		   utils.py
# imgaug			      project_summary.pdf
# infer.py		      __pycache__

# %%
# !ls save
# Out:
# C7,64,2C7,64,1M2C7,64,2C7,64,1M2C7,64,2C7,64,1M2

# %%
# !zip -r saves.zip save
# Out:
#   adding: save/ (stored 0%)
#   adding: save/C7,64,2C7,64,1M2C7,64,2C7,64,1M2C7,64,2C7,64,1M2/ (stored 0%)
#   adding: save/C7,64,2C7,64,1M2C7,64,2C7,64,1M2C7,64,2C7,64,1M2/2019-04-02_172105/ (stored 0%)
#   adding: save/C7,64,2C7,64,1M2C7,64,2C7,64,1M2C7,64,2C7,64,1M2/2019-04-02_172105/model.ckpt-900.meta (deflated 11%)
#   adding: save/C7,64,2C7,64,1M2C7,64,2C7,64,1M2C7,64,2C7,64,1M2/2019-04-02_172105/model.ckpt-1300.meta (deflated 9%)
#   adding: save/C7,64,2C7,64,1M2C7,64,2C7,64,1M2C7,64,2C7,64,1M2/2019-04-02_172105/model.ckpt-100.meta (deflated 40%)
#   adding: save/C7,64,2C7,64,1M2C7,64,2C7,64,1M2C7,64,2C7,64,1M2/2019-04-02_172105/model.ckpt-1900.index (deflated 63%)
#   adding: save/C7,64,2C7,64,1M2C7,64,2C7,64,1M2C7,64,2C7,64,1M2/2019-04-02_172105/model.ckpt-600.data-00000-of-00001 (deflated 8%)
#   adding: save/C7,64,2C7,64,1M2C7,64,2C7,64,1M2C7,64,2C7,64,1M2/2019-04-02_172105/model.ckpt-1900.data-00000-of-00001 (deflated 8%)
# ...

# %%
# !ls
# Out:
# conv2d.py		      infer.py		   __pycache__
# convolutional_autoencoder.py  layer.py		   README.md
# data128_128		      libs		   results.png
# data250_250		      logs		   sample_data
# data28_28		      max_pool_2d.py	   save
# example.txt		      model.png		   saves.zip
# image_plots		      notebooks		   Tensorflow-Segmentation
# imgaug			      project_summary.pdf  utils.py

# %%
from google.colab import files

files.download('./saves.zip')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-17-dcc78ba6fe3e> in <module>()
#       1 from google.colab import files
#       2
# ----> 3 files.download('./saves.zip')
#
# /usr/local/lib/python3.6/dist-packages/google/colab/files.py in download(filename)
#     176       'port': port,
#     177       'path': _os.path.abspath(filename),
# --> 178       'name': _os.path.basename(filename),
#     179   })
#
# /usr/local/lib/python3.6/dist-packages/google/colab/output/_js.py in eval_js(script, ignore_result)
#      37   if ignore_result:
#      38     return
# ---> 39   return _message.read_reply_from_input(request_id)
#      40
#      41
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#     104         reply.get('colab_msg_id') == message_id):
#     105       if 'error' in reply:
# ...

# %%
# !ls -l
# Out:
# total 240356
# -rw-r--r-- 1 root root      2597 Apr  2 17:18 conv2d.py
# -rw-r--r-- 1 root root     15154 Apr  2 17:18 convolutional_autoencoder.py
# drwxr-xr-x 5 root root      4096 Apr  2 17:18 data128_128
# drwxr-xr-x 5 root root      4096 Apr  2 17:18 data250_250
# drwxr-xr-x 5 root root      4096 Apr  2 17:18 data28_28
# -rw-r--r-- 1 root root        12 Apr  2 18:08 example.txt
# drwxr-xr-x 2 root root      4096 Apr  2 18:02 image_plots
# drwxr-xr-x 5 root root      4096 Apr  2 17:21 imgaug
# -rw-r--r-- 1 root root      2979 Apr  2 17:18 infer.py
# -rw-r--r-- 1 root root       166 Apr  2 17:18 layer.py
# drwxr-xr-x 3 root root      4096 Apr  2 17:21 libs
# drwxr-xr-x 3 root root      4096 Apr  2 17:21 logs
# -rw-r--r-- 1 root root       636 Apr  2 17:18 max_pool_2d.py
# -rw-r--r-- 1 root root     65059 Apr  2 17:18 model.png
# drwxr-xr-x 2 root root      4096 Apr  2 17:18 notebooks
# -rw-r--r-- 1 root root   3254467 Apr  2 17:18 project_summary.pdf
# ...

# %%
# !ls image_plots
# Out:
# figure1000.jpg	figure1400.jpg	figure1900.jpg	figure2300.jpg	figure700.jpg
# figure100.jpg	figure1500.jpg	figure2000.jpg	figure300.jpg	figure800.jpg
# figure1100.jpg	figure1600.jpg	figure200.jpg	figure400.jpg	figure900.jpg
# figure1200.jpg	figure1700.jpg	figure2100.jpg	figure500.jpg
# figure1300.jpg	figure1800.jpg	figure2200.jpg	figure600.jpg

# %%
# !zip -r image_plots.zip image_plots
# Out:
#   adding: image_plots/ (stored 0%)
#   adding: image_plots/figure900.jpg (deflated 16%)
#   adding: image_plots/figure2000.jpg (deflated 16%)
#   adding: image_plots/figure400.jpg (deflated 15%)
#   adding: image_plots/figure300.jpg (deflated 15%)
#   adding: image_plots/figure700.jpg (deflated 15%)
#   adding: image_plots/figure2200.jpg (deflated 16%)
#   adding: image_plots/figure1500.jpg (deflated 15%)
#   adding: image_plots/figure1300.jpg (deflated 15%)
#   adding: image_plots/figure1600.jpg (deflated 15%)
#   adding: image_plots/figure1900.jpg (deflated 15%)
#   adding: image_plots/figure1400.jpg (deflated 15%)
#   adding: image_plots/figure600.jpg (deflated 15%)
#   adding: image_plots/figure1200.jpg (deflated 15%)
#   adding: image_plots/figure2100.jpg (deflated 16%)
#   adding: image_plots/figure1000.jpg (deflated 15%)
#   adding: image_plots/figure1800.jpg (deflated 16%)
#   adding: image_plots/figure100.jpg (deflated 15%)
# ...

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /gdrive

# %%
with open('/gdrive/My Drive/foo.txt', 'w') as f:
  f.write('Hello Google Drive!')
# !cat '/gdrive/My Drive/foo.txt'
# Out:
# Hello Google Drive!

# %%
# !cp 'image_plots.zip' '/gdrive/My Drive/image_plots.zip'

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-2d1c6bd1-eac7-4c7d-8f1c-96eaea82dfb3" name="files[]" multiple disabled />
#      <output id="result-2d1c6bd1-eac7-4c7d-8f1c-96eaea82dfb3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving convolutional_autoencoder.py to convolutional_autoencoder (1).py
# User uploaded file "convolutional_autoencoder.py" with length 15462 bytes

# %%
# !mv 'convolutional_autoencoder (1).py' convolutional_autoencoder.py
